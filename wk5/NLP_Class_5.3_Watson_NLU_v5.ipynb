# %% [markdown]
# ## Natural Language Understanding
# https://natural-language-understanding-demo.mybluemix.net/

# %% [markdown]
# Free 6 months trial for students: https://ibm.onthehub.com and click on "Students".
# Offer includes IBM Cloud as well as Watson services

# %%
#!pip install watson_developer_cloud

# %%
import sys
import os
import json
import re
import pandas as pd
sys.path.append(os.path.join(os.getcwd(),'..'))
import watson_developer_cloud
from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 import Features, EntitiesOptions, KeywordsOptions, ConceptsOptions, RelationsOptions, SentimentOptions, SemanticRolesOptions, EmotionOptions, CategoriesOptions

# %%
natural_language_understanding = watson_developer_cloud.NaturalLanguageUnderstandingV1(version='2017-03-02',
                                                            username='username',
                                                            password='password')

# %% [markdown]
# https://watson-api-explorer.mybluemix.net/apis/natural-language-understanding-v1

# %% [markdown]
# #### Concepts
#
# Identify general concepts that are referenced or alluded to in your content. Concepts that are detected typically have an associated link to a DBpedia resource.
#
# #### Entities
# Detect important people, places, geopolitical entities and other types of entities in your content. Entity detection recognizes consecutive coreferences of each entity. For example, analysis of the following text would count "Barack Obama" and "He" as the same entity:
# "Barack Obama was the 44th President of the United States. He took office in January 2009."
#
# #### Keywords
# Determine the most important keywords in your content. Keyword phrases are organized by relevance in the results.
#
# #### Categories
# Categorize your content into a hierarchical 5-level taxonomy. For example, "Leonardo DiCaprio won an Oscar" returns "/art and entertainment/movies and tv/movies" as the most confident classification.
#
# #### Sentiment
# Determine whether your content conveys postive or negative sentiment. Sentiment information can be returned for detected entities, keywords, or user-specified target phrases found in the text.
#
# #### Emotion
# Detect anger, disgust, fear, joy, or sadness that is conveyed by your content. Emotion information can be returned for detected entities, keywords, or user-specified target phrases found in the text.
#
# #### Relations
# Recognize when two entities are related, and identify the type of relation. For example, you can identify an "awardedTo" relation between an award and its recipient.
#
# #### Semantic Roles
# Parse sentences into subject-action-object form, and identify entities and keywords that are subjects or objects of an action.

# %% [markdown]
# ## Analyzing text

# %%
text='After overtaking BMW last year as the world’s largest luxury automaker, \
Mercedes-Benz is turning its attention to a newer, untapped audience: \
millennials seeking smaller cars as they progress through the stages of early adulthood.'

# %%
response = natural_language_understanding.analyze(
            language = "en", text = text,
            features = Features(
                        entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            ))

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 1
#   },
#   "language": "en",
#   "entities": [
#     {
#       "type": "Company",
#       "text": "BMW",
#       "sentiment": {
#         "score": 0.216764,
#         "label": "positive"
#       },
#       "relevance": 0.33,
#       "emotion": {
#         "sadness": 0.212793,
#         "joy": 0.507769,
#         "fear": 0.064729,
#         "disgust": 0.03569,
#         "anger": 0.030211
#       },
#       "disambiguation": {
#         "subtype": [
#           "Engine",
#           "AutomobileCompany",
#           "AwardWinner"
#         ],
#         "name": "BMW",
#         "dbpedia_resource": "http://dbpedia.org/resource/BMW"
#       },
#       "count": 1
#     },
#     {
#       "type": "Company",
#       "text": "Mercedes-Benz",
#       "sentiment": {
#         "score": 0.736997,
#         "label": "positive"
#       },
#       "relevance": 0.33,
#       "emotion": {
#         "sadness": 0.375508,
#         "joy": 0.255631,
#         "fear": 0.137987,
#         "disgust": 0.036792,
#         "anger": 0.093049
#       },
#       "disambiguation": {
#         "subtype": [
#           "AutomotiveDesigner",
#           "AwardWinner"
#         ],
#         "name": "Mercedes-Benz",
#         "dbpedia_resource": "http://dbpedia.org/resource/Mercedes-Benz"
#       },
#       "count": 1
#     }
#   ]
# }

# %%
response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            ))

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 1
#   },
#   "language": "en",
#   "keywords": [
#     {
#       "text": "largest luxury automaker",
#       "sentiment": {
#         "score": 0.216764,
#         "label": "positive"
#       },
#       "relevance": 0.951351,
#       "emotion": {
#         "sadness": 0.212793,
#         "joy": 0.507769,
#         "fear": 0.064729,
#         "disgust": 0.03569,
#         "anger": 0.030211
#       }
#     },
#     {
#       "text": "untapped audience",
#       "sentiment": {
#         "score": 0.769293,
#         "label": "positive"
#       },
#       "relevance": 0.758759,
#       "emotion": {
#         "sadness": 0.151545,
#         "joy": 0.174219,
#         "fear": 0.093654,
#         "disgust": 0.072945,
#         "anger": 0.08686
#       }
#     },
#     {
#       "text": "early adulthood",
#       "sentiment": {
#         "score": 0.583717,
#         "label": "positive"
#       },
#       "relevance": 0.673927,
#       "emotion": {
#         "sadness": 0.073033,
#         "joy": 0.637075,
#         "fear": 0.078259,
#         "disgust": 0.123112,
#         "anger": 0.073193
#       }
#     },
#     {
#       "text": "smaller cars",
#       "sentiment": {
#         "score": 0.583717,
#         "label": "positive"
#       },
#       "relevance": 0.646383,
#       "emotion": {
#         "sadness": 0.073033,
#         "joy": 0.637075,
#         "fear": 0.078259,
#         "disgust": 0.123112,
#         "anger": 0.073193
#       }
#     },
#     {
#       "text": "Mercedes-Benz",
#       "sentiment": {
#         "score": 0.736997,
#         "label": "positive"
#       },
#       "relevance": 0.43985,
#       "emotion": {
#         "sadness": 0.375508,
#         "joy": 0.255631,
#         "fear": 0.137987,
#         "disgust": 0.036792,
#         "anger": 0.093049
#       }
#     },
#     {
#       "text": "BMW",
#       "sentiment": {
#         "score": 0.216764,
#         "label": "positive"
#       },
#       "relevance": 0.411539,
#       "emotion": {
#         "sadness": 0.212793,
#         "joy": 0.507769,
#         "fear": 0.064729,
#         "disgust": 0.03569,
#         "anger": 0.030211
#       }
#     },
#     {
#       "text": "attention",
#       "sentiment": {
#         "score": 0.736997,
#         "label": "positive"
#       },
#       "relevance": 0.4046,
#       "emotion": {
#         "sadness": 0.375508,
#         "joy": 0.255631,
#         "fear": 0.137987,
#         "disgust": 0.036792,
#         "anger": 0.093049
#       }
#     },
#     {
#       "text": "stages",
#       "sentiment": {
#         "score": 0.583717,
#         "label": "positive"
#       },
#       "relevance": 0.393549,
#       "emotion": {
#         "sadness": 0.073033,
#         "joy": 0.637075,
#         "fear": 0.078259,
#         "disgust": 0.123112,
#         "anger": 0.073193
#       }
#     },
#     {
#       "text": "world",
#       "sentiment": {
#         "score": 0.216764,
#         "label": "positive"
#       },
#       "relevance": 0.350317
#     }
#   ]
# }

# %%
response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            ))

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 1
#   },
#   "language": "en",
#   "concepts": [
#     {
#       "text": "BMW",
#       "relevance": 0.888452,
#       "dbpedia_resource": "http://dbpedia.org/resource/BMW"
#     },
#     {
#       "text": "Mercedes-Benz",
#       "relevance": 0.888266,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mercedes-Benz"
#     },
#     {
#       "text": "Automotive industry",
#       "relevance": 0.882851,
#       "dbpedia_resource": "http://dbpedia.org/resource/Automotive_industry"
#     },
#     {
#       "text": "Luxury vehicle",
#       "relevance": 0.852593,
#       "dbpedia_resource": "http://dbpedia.org/resource/Luxury_vehicle"
#     },
#     {
#       "text": "Karl Benz",
#       "relevance": 0.780259,
#       "dbpedia_resource": "http://dbpedia.org/resource/Karl_Benz"
#     },
#     {
#       "text": "Diesel engine",
#       "relevance": 0.765713,
#       "dbpedia_resource": "http://dbpedia.org/resource/Diesel_engine"
#     },
#     {
#       "text": "World",
#       "relevance": 0.7476,
#       "dbpedia_resource": "http://dbpedia.org/resource/World"
#     },
#     {
#       "text": "Adult",
#       "relevance": 0.72744,
#       "dbpedia_resource": "http://dbpedia.org/resource/Adult"
#     },
#     {
#       "text": "Adulthood",
#       "relevance": 0.714,
#       "dbpedia_resource": "http://dbpedia.org/resource/Adulthood"
#     },
#     {
#       "text": "Earth",
#       "relevance": 0.6804,
#       "dbpedia_resource": "http://dbpedia.org/resource/Earth"
#     }
#   ]
# }

# %%
response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        categories = CategoriesOptions()))

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 2
#   },
#   "relations": [
#     {
#       "type": "basedIn",
#       "sentence": "After overtaking BMW last year as the world's largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "score": 0.808415,
#       "arguments": [
#         {
#           "text": "automaker",
#           "location": [
#             61,
#             70
#           ],
#           "entities": [
#             {
#               "type": "Organization",
#               "text": "Mercedes-Benz",
#               "disambiguation": {
#                 "subtype": [
#                   "Commercial"
#                 ]
#               }
#             }
#           ]
#         },
#         {
#           "text": "world",
#           "location": [
#             38,
#             43
#           ],
#           "entities": [
#             {
#               "type": "GeopoliticalEntity",
#               "text": "world",
#               "disambiguation": {
#                 "subtype": [
#                   "Area"
#                 ]
#               }
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "employedBy",
#       "sentence": "After overtaking BMW last year as the world's largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "score": 0.31143,
#       "arguments": [
#         {
#           "text": "audience",
#           "location": [
#             132,
#             140
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "audience"
#             }
#           ]
#         },
#         {
#           "text": "its",
#           "location": [
#             97,
#             100
#           ],
#           "entities": [
#             {
#               "type": "Organization",
#               "text": "Mercedes-Benz",
#               "disambiguation": {
#                 "subtype": [
#                   "Commercial"
#                 ]
#               }
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "employedBy",
#       "sentence": "After overtaking BMW last year as the world's largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "score": 0.277355,
#       "arguments": [
#         {
#           "text": "millennials",
#           "location": [
#             142,
#             153
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "millennials"
#             }
#           ]
#         },
#         {
#           "text": "its",
#           "location": [
#             97,
#             100
#           ],
#           "entities": [
#             {
#               "type": "Organization",
#               "text": "Mercedes-Benz",
#               "disambiguation": {
#                 "subtype": [
#                   "Commercial"
#                 ]
#               }
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "locatedAt",
#       "sentence": "After overtaking BMW last year as the world's largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "score": 0.636426,
#       "arguments": [
#         {
#           "text": "millennials",
#           "location": [
#             142,
#             153
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "millennials"
#             }
#           ]
#         },
#         {
#           "text": "cars",
#           "location": [
#             170,
#             174
#           ],
#           "entities": [
#             {
#               "type": "Vehicle",
#               "text": "cars"
#             }
#           ]
#         }
#       ]
#     }
#   ],
#   "language": "en",
#   "categories": [
#     {
#       "score": 0.554889,
#       "label": "/automotive and vehicles/cars"
#     },
#     {
#       "score": 0.152065,
#       "label": "/automotive and vehicles/vehicle brands/mercedes-benz"
#     },
#     {
#       "score": 0.130826,
#       "label": "/business and industrial"
#     }
#   ]
# }

# %%
response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            ))

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 1
#   },
#   "sentiment": {
#     "document": {
#       "score": 0.906302,
#       "label": "positive"
#     }
#   },
#   "language": "en"
# }

# %%
response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            ))

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 1
#   },
#   "semantic_roles": [
#     {
#       "subject": {
#         "text": "the world",
#         "keywords": [
#           {
#             "text": "world"
#           }
#         ]
#       },
#       "sentence": "After overtaking BMW last year as the world\u2019s largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "object": {
#         "text": "largest luxury automaker",
#         "keywords": [
#           {
#             "text": "largest luxury automaker"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "has",
#           "tense": "present"
#         },
#         "text": "s",
#         "normalized": "s"
#       }
#     },
#     {
#       "subject": {
#         "text": "Mercedes-Benz",
#         "keywords": [
#           {
#             "text": "Mercedes-Benz"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Company",
#             "text": "Mercedes-Benz",
#             "disambiguation": {
#               "subtype": [
#                 "Organization",
#                 "AutomotiveDesigner",
#                 "AwardWinner"
#               ],
#               "name": "Mercedes-Benz",
#               "dbpedia_resource": "http://dbpedia.org/resource/Mercedes-Benz"
#             }
#           }
#         ]
#       },
#       "sentence": "After overtaking BMW last year as the world\u2019s largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "object": {
#         "text": "turning its attention to a newer, untapped audience",
#         "keywords": [
#           {
#             "text": "untapped audience"
#           },
#           {
#             "text": "attention"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "is",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "Mercedes-Benz",
#         "keywords": [
#           {
#             "text": "Mercedes-Benz"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Company",
#             "text": "Mercedes-Benz",
#             "disambiguation": {
#               "subtype": [
#                 "Organization",
#                 "AutomotiveDesigner",
#                 "AwardWinner"
#               ],
#               "name": "Mercedes-Benz",
#               "dbpedia_resource": "http://dbpedia.org/resource/Mercedes-Benz"
#             }
#           }
#         ]
#       },
#       "sentence": "After overtaking BMW last year as the world\u2019s largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "object": {
#         "text": "its attention",
#         "keywords": [
#           {
#             "text": "attention"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "turn",
#           "tense": "present"
#         },
#         "text": "is turning",
#         "normalized": "be turn"
#       }
#     },
#     {
#       "subject": {
#         "text": "millennials",
#         "keywords": [
#           {
#             "text": "millennials"
#           }
#         ]
#       },
#       "sentence": "After overtaking BMW last year as the world\u2019s largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "object": {
#         "text": "smaller cars",
#         "keywords": [
#           {
#             "text": "smaller cars"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "seek",
#           "tense": "present"
#         },
#         "text": "seeking",
#         "normalized": "seek"
#       }
#     }
#   ],
#   "language": "en"
# }

# %%
response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            ))

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 1
#   },
#   "language": "en",
#   "emotion": {
#     "document": {
#       "emotion": {
#         "sadness": 0.19455,
#         "joy": 0.595719,
#         "fear": 0.069535,
#         "disgust": 0.050423,
#         "anger": 0.046226
#       }
#     }
#   }
# }

# %%
response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        categories = CategoriesOptions()
            ))

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 1
#   },
#   "language": "en",
#   "categories": [
#     {
#       "score": 0.554889,
#       "label": "/automotive and vehicles/cars"
#     },
#     {
#       "score": 0.152065,
#       "label": "/automotive and vehicles/vehicle brands/mercedes-benz"
#     },
#     {
#       "score": 0.130826,
#       "label": "/business and industrial"
#     }
#   ]
# }

# %% [markdown]
# ## Analyzing URLS

# %%
url='http://www.chicagotribune.com/news/local/breaking/ct-fbi-chase-bank-branch-robbed-on-far-south-side-20170524-story.html'

response = natural_language_understanding.analyze(
            url = url,
            features = Features(
                        entities = EntitiesOptions(sentiment = True, emotion = True),
                        keywords = KeywordsOptions(sentiment = True, emotion = True),
                        concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            ))

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 811,
#     "features": 3
#   },
#   "retrieved_url": "http://www.chicagotribune.com/news/local/breaking/ct-fbi-chase-bank-branch-robbed-on-far-south-side-20170524-story.html",
#   "language": "en",
#   "keywords": [
#     {
#       "text": "would-be robber",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.97343,
#       "emotion": {
#         "sadness": 0.23608,
#         "joy": 0.086439,
#         "fear": 0.177302,
#         "disgust": 0.416375,
#         "anger": 0.214233
#       }
#     },
#     {
#       "text": "Calumet Heights neighborhood",
#       "sentiment": {
#         "score": -0.567525,
#         "label": "negative"
#       },
#       "relevance": 0.879791,
#       "emotion": {
#         "sadness": 0.376757,
#         "joy": 0.307912,
#         "fear": 0.100655,
#         "disgust": 0.191158,
#         "anger": 0.098523
#       }
#     },
#     {
#       "text": "Chase Bank",
#       "sentiment": {
#         "score": -0.567525,
#         "label": "negative"
#       },
#       "relevance": 0.864905,
#       "emotion": {
#         "sadness": 0.396781,
#         "joy": 0.227727,
#         "fear": 0.10534,
#         "disgust": 0.139012,
#         "anger": 0.108463
#       }
#     },
#     {
#       "text": "Chase Bank branch",
#       "sentiment": {
#         "score": -0.567525,
#         "label": "negative"
#       },
#       "relevance": 0.847705,
#       "emotion": {
#         "sadness": 0.376757,
#         "joy": 0.307912,
#         "fear": 0.100655,
#         "disgust": 0.191158,
#         "anger": 0.098523
#       }
#     },
#     {
#       "text": "S. Jeffery Blvd.",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.772957
#     },
#     {
#       "text": "FBI spokesman",
#       "sentiment": {
#         "score": -0.404007,
#         "label": "negative"
#       },
#       "relevance": 0.761774,
#       "emotion": {
#         "sadness": 0.441087,
#         "joy": 0.019109,
#         "fear": 0.149402,
#         "disgust": 0.40223,
#         "anger": 0.277893
#       }
#     },
#     {
#       "text": "yellow work vest",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.723126,
#       "emotion": {
#         "sadness": 0.243479,
#         "joy": 0.301258,
#         "fear": 0.189485,
#         "disgust": 0.07674,
#         "anger": 0.180288
#       }
#     },
#     {
#       "text": "dark colored pants",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.705049,
#       "emotion": {
#         "sadness": 0.337738,
#         "joy": 0.05809,
#         "fear": 0.417989,
#         "disgust": 0.297746,
#         "anger": 0.106481
#       }
#     },
#     {
#       "text": "Wednesday morning",
#       "sentiment": {
#         "score": -0.567525,
#         "label": "negative"
#       },
#       "relevance": 0.461158,
#       "emotion": {
#         "sadness": 0.376757,
#         "joy": 0.307912,
#         "fear": 0.100655,
#         "disgust": 0.191158,
#         "anger": 0.098523
#       }
#     },
#     {
#       "text": "white hardhat",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.452673,
#       "emotion": {
#         "sadness": 0.130342,
#         "joy": 0.146316,
#         "fear": 0.076505,
#         "disgust": 0.378072,
#         "anger": 0.085607
#       }
#     },
#     {
#       "text": "Armour mask",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.421174,
#       "emotion": {
#         "sadness": 0.426719,
#         "joy": 0.115403,
#         "fear": 0.122952,
#         "disgust": 0.442834,
#         "anger": 0.089563
#       }
#     },
#     {
#       "text": "slim build",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.408131,
#       "emotion": {
#         "sadness": 0.090018,
#         "joy": 0.299305,
#         "fear": 0.055553,
#         "disgust": 0.060972,
#         "anger": 0.04714
#       }
#     },
#     {
#       "text": "Earlier information",
#       "sentiment": {
#         "score": -0.527533,
#         "label": "negative"
#       },
#       "relevance": 0.404156,
#       "emotion": {
#         "sadness": 0.059115,
#         "joy": 0.427062,
#         "fear": 0.029166,
#         "disgust": 0.009774,
#         "anger": 0.024569
#       }
#     },
#     {
#       "text": "surveillance photo",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.361838,
#       "emotion": {
#         "sadness": 0.193412,
#         "joy": 0.095615,
#         "fear": 0.188651,
#         "disgust": 0.31484,
#         "anger": 0.211257
#       }
#     },
#     {
#       "text": "Chicago office",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.359322,
#       "emotion": {
#         "sadness": 0.221163,
#         "joy": 0.093333,
#         "fear": 0.135639,
#         "disgust": 0.283389,
#         "anger": 0.203137
#       }
#     },
#     {
#       "text": "low resolution",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.35032,
#       "emotion": {
#         "sadness": 0.401284,
#         "joy": 0.026079,
#         "fear": 0.153046,
#         "disgust": 0.468145,
#         "anger": 0.08525
#       }
#     },
#     {
#       "text": "black man",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.349437,
#       "emotion": {
#         "sadness": 0.265193,
#         "joy": 0.099865,
#         "fear": 0.160373,
#         "disgust": 0.390831,
#         "anger": 0.157866
#       }
#     },
#     {
#       "text": "robbery",
#       "sentiment": {
#         "score": -0.46293,
#         "label": "negative"
#       },
#       "relevance": 0.276157,
#       "emotion": {
#         "sadness": 0.168016,
#         "joy": 0.108108,
#         "fear": 0.087392,
#         "disgust": 0.017073,
#         "anger": 0.030652
#       }
#     }
#   ],
#   "entities": [
#     {
#       "type": "Organization",
#       "text": "FBI",
#       "sentiment": {
#         "score": -0.404007,
#         "label": "negative"
#       },
#       "relevance": 0.902431,
#       "emotion": {
#         "sadness": 0.1792,
#         "joy": 0.088157,
#         "fear": 0.186275,
#         "disgust": 0.3797,
#         "anger": 0.310301
#       },
#       "disambiguation": {
#         "subtype": [
#           "GovernmentAgency",
#           "GovernmentalBody"
#         ],
#         "name": "Federal Bureau of Investigation",
#         "dbpedia_resource": "http://dbpedia.org/resource/Federal_Bureau_of_Investigation"
#       },
#       "count": 5
#     },
#     {
#       "type": "Crime",
#       "text": "attempted robbery",
#       "sentiment": {
#         "score": -0.46293,
#         "label": "negative"
#       },
#       "relevance": 0.488685,
#       "emotion": {
#         "sadness": 0.168016,
#         "joy": 0.108108,
#         "fear": 0.087392,
#         "disgust": 0.017073,
#         "anger": 0.030652
#       },
#       "count": 2
#     },
#     {
#       "type": "Company",
#       "text": "Chase Bank",
#       "sentiment": {
#         "score": -0.567525,
#         "label": "negative"
#       },
#       "relevance": 0.46852,
#       "emotion": {
#         "sadness": 0.396781,
#         "joy": 0.227727,
#         "fear": 0.10534,
#         "disgust": 0.139012,
#         "anger": 0.108463
#       },
#       "disambiguation": {
#         "subtype": [],
#         "name": "Chase (bank)",
#         "dbpedia_resource": "http://dbpedia.org/resource/Chase_(bank)"
#       },
#       "count": 2
#     },
#     {
#       "type": "Location",
#       "text": "Calumet Heights",
#       "sentiment": {
#         "score": -0.567525,
#         "label": "negative"
#       },
#       "relevance": 0.259034,
#       "emotion": {
#         "sadness": 0.376757,
#         "joy": 0.307912,
#         "fear": 0.100655,
#         "disgust": 0.191158,
#         "anger": 0.098523
#       },
#       "disambiguation": {
#         "subtype": [
#           "City"
#         ]
#       },
#       "count": 1
#     },
#     {
#       "type": "Person",
#       "text": "rob",
#       "sentiment": {
#         "score": -0.567525,
#         "label": "negative"
#       },
#       "relevance": 0.21717,
#       "emotion": {
#         "sadness": 0.376757,
#         "joy": 0.307912,
#         "fear": 0.100655,
#         "disgust": 0.191158,
#         "anger": 0.098523
#       },
#       "count": 1
#     },
#     {
#       "type": "Location",
#       "text": "Chicago",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.189571,
#       "emotion": {
#         "sadness": 0.221163,
#         "joy": 0.093333,
#         "fear": 0.135639,
#         "disgust": 0.283389,
#         "anger": 0.203137
#       },
#       "disambiguation": {
#         "subtype": [
#           "City"
#         ],
#         "name": "Chicago",
#         "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#       },
#       "count": 1
#     },
#     {
#       "type": "Quantity",
#       "text": "5-foot",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.189571,
#       "count": 2
#     }
#   ],
#   "concepts": [
#     {
#       "text": "Bank robbery",
#       "relevance": 0.951185,
#       "dbpedia_resource": "http://dbpedia.org/resource/Bank_robbery"
#     },
#     {
#       "text": "White people",
#       "relevance": 0.852973,
#       "dbpedia_resource": "http://dbpedia.org/resource/White_people"
#     },
#     {
#       "text": "Color",
#       "relevance": 0.749349,
#       "dbpedia_resource": "http://dbpedia.org/resource/Color"
#     },
#     {
#       "text": "Robbery",
#       "relevance": 0.744865,
#       "dbpedia_resource": "http://dbpedia.org/resource/Robbery"
#     },
#     {
#       "text": "United Kingdom",
#       "relevance": 0.723957,
#       "dbpedia_resource": "http://dbpedia.org/resource/United_Kingdom"
#     },
#     {
#       "text": "Crime",
#       "relevance": 0.691178,
#       "dbpedia_resource": "http://dbpedia.org/resource/Crime"
#     },
#     {
#       "text": "African American",
#       "relevance": 0.687616,
#       "dbpedia_resource": "http://dbpedia.org/resource/African_American"
#     },
#     {
#       "text": "Theft",
#       "relevance": 0.677833,
#       "dbpedia_resource": "http://dbpedia.org/resource/Theft"
#     },
#     {
#       "text": "Chicago",
#       "relevance": 0.618643,
#       "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#     }
#   ]
# }

# %%
response = natural_language_understanding.analyze(
            url = url,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            ))

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 811,
#     "features": 1
#   },
#   "semantic_roles": [
#     {
#       "subject": {
#         "text": "A man",
#         "keywords": [
#           {
#             "text": "man"
#           }
#         ]
#       },
#       "sentence": "A man tried to rob a Chase Bank branch Wednesday morning in the Calumet Heights neighborhood on the Far South Side, the FBI said.",
#       "object": {
#         "text": "to rob a Chase Bank branch",
#         "keywords": [
#           {
#             "text": "Chase Bank branch"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "rob"
#           },
#           {
#             "type": "Company",
#             "text": "Chase Bank",
#             "disambiguation": {
#               "subtype": [
#                 "Company"
#               ],
#               "name": "Chase (bank)",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chase_(bank)"
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "try",
#           "tense": "past"
#         },
#         "text": "tried",
#         "normalized": "try"
#       }
#     },
#     {
#       "subject": {
#         "text": "A man",
#         "keywords": [
#           {
#             "text": "man"
#           }
#         ]
#       },
#       "sentence": "A man tried to rob a Chase Bank branch Wednesday morning in the Calumet Heights neighborhood on the Far South Side, the FBI said.",
#       "object": {
#         "text": "a Chase Bank branch",
#         "keywords": [
#           {
#             "text": "Chase Bank branch"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Company",
#             "text": "Chase Bank",
#             "disambiguation": {
#               "subtype": [
#                 "Company"
#               ],
#               "name": "Chase (bank)",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chase_(bank)"
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "rob",
#           "tense": "future"
#         },
#         "text": "tried to rob",
#         "normalized": "try to rob"
#       }
#     },
#     {
#       "subject": {
#         "text": "the FBI",
#         "keywords": [
#           {
#             "text": "FBI"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "FBI",
#             "disambiguation": {
#               "subtype": [
#                 "GovernmentAgency",
#                 "GovernmentalBody"
#               ],
#               "name": "Federal Bureau of Investigation",
#               "dbpedia_resource": "http://dbpedia.org/resource/Federal_Bureau_of_Investigation"
#             }
#           }
#         ]
#       },
#       "sentence": "A man tried to rob a Chase Bank branch Wednesday morning in the Calumet Heights neighborhood on the Far South Side, the FBI said.",
#       "object": {
#         "text": "A man tried to rob a Chase Bank branch Wednesday morning in the Calumet Heights neighborhood on the Far South Side",
#         "keywords": [
#           {
#             "text": "Calumet Heights neighborhood"
#           },
#           {
#             "text": "Chase Bank branch"
#           },
#           {
#             "text": "Wednesday morning"
#           },
#           {
#             "text": "man"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "rob"
#           },
#           {
#             "type": "Company",
#             "text": "Chase Bank",
#             "disambiguation": {
#               "subtype": [
#                 "Company"
#               ],
#               "name": "Chase (bank)",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chase_(bank)"
#             }
#           },
#           {
#             "type": "Location",
#             "text": "Calumet Heights",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "say",
#           "tense": "past"
#         },
#         "text": "said",
#         "normalized": "say"
#       }
#     },
#     {
#       "subject": {
#         "text": "The attempted robbery",
#         "keywords": [
#           {
#             "text": "robbery"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Crime",
#             "text": "attempted robbery"
#           }
#         ]
#       },
#       "sentence": " The attempted robbery happened shortly after 8:20 a.m. at a Chase Bank at 9450 S. Jeffery Blvd., officials said.",
#       "action": {
#         "verb": {
#           "text": "happen",
#           "tense": "past"
#         },
#         "text": "happened",
#         "normalized": "happen"
#       }
#     },
#     {
#       "subject": {
#         "text": "officials",
#         "keywords": [
#           {
#             "text": "officials"
#           }
#         ]
#       },
#       "sentence": " The attempted robbery happened shortly after 8:20 a.m. at a Chase Bank at 9450 S. Jeffery Blvd., officials said.",
#       "action": {
#         "verb": {
#           "text": "say",
#           "tense": "past"
#         },
#         "text": "said",
#         "normalized": "say"
#       }
#     },
#     {
#       "subject": {
#         "text": "the robbery",
#         "keywords": [
#           {
#             "text": "robbery"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Crime",
#             "text": "attempted robbery"
#           }
#         ]
#       },
#       "sentence": " Earlier information had been that the robbery was successful, but that was not correct, an FBI spokesman said.",
#       "object": {
#         "text": "successful"
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "past"
#         },
#         "text": "was",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "an FBI spokesman",
#         "keywords": [
#           {
#             "text": "FBI spokesman"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "FBI",
#             "disambiguation": {
#               "subtype": [
#                 "GovernmentAgency",
#                 "GovernmentalBody"
#               ],
#               "name": "Federal Bureau of Investigation",
#               "dbpedia_resource": "http://dbpedia.org/resource/Federal_Bureau_of_Investigation"
#             }
#           }
#         ]
#       },
#       "sentence": " Earlier information had been that the robbery was successful, but that was not correct, an FBI spokesman said.",
#       "object": {
#         "text": "Earlier information had been that the robbery was successful, but that was not correct",
#         "keywords": [
#           {
#             "text": "Earlier information"
#           },
#           {
#             "text": "robbery"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Crime",
#             "text": "attempted robbery"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "say",
#           "tense": "past"
#         },
#         "text": "said",
#         "normalized": "say"
#       }
#     },
#     {
#       "subject": {
#         "text": "The would-be robber",
#         "keywords": [
#           {
#             "text": "would-be robber"
#           }
#         ]
#       },
#       "sentence": " The would-be robber was described as a black man, standing about 5-foot-5 to 5-foot-7, with a slim build.",
#       "object": {
#         "text": "described as a black man",
#         "keywords": [
#           {
#             "text": "black man"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "past"
#         },
#         "text": "was",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "The would-be robber",
#         "keywords": [
#           {
#             "text": "would-be robber"
#           }
#         ]
#       },
#       "sentence": " The would-be robber was described as a black man, standing about 5-foot-5 to 5-foot-7, with a slim build.",
#       "object": {
#         "text": "as a black man, standing about 5-foot-5 to 5-foot-7, with a slim build",
#         "keywords": [
#           {
#             "text": "slim build"
#           },
#           {
#             "text": "black man"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Quantity",
#             "text": "5-foot"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "describe",
#           "tense": "past"
#         },
#         "text": "was described",
#         "normalized": "be describe"
#       }
#     },
#     {
#       "subject": {
#         "text": "a black man",
#         "keywords": [
#           {
#             "text": "black man"
#           }
#         ]
#       },
#       "sentence": " The would-be robber was described as a black man, standing about 5-foot-5 to 5-foot-7, with a slim build.",
#       "object": {
#         "text": "about 5-foot-5",
#         "entities": [
#           {
#             "type": "Quantity",
#             "text": "5-foot"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "stand",
#           "tense": "present"
#         },
#         "text": "standing",
#         "normalized": "stand"
#       }
#     },
#     {
#       "subject": {
#         "text": "He"
#       },
#       "sentence": " He was wearing a white hardhat, an orange and yellow work vest, and dark colored pants, with a black Under Armour mask covering his face, according to the FBI.",
#       "object": {
#         "text": "wearing a white hardhat, an orange and yellow work vest, and dark colored pants, with a black Under Armour mask covering his face",
#         "keywords": [
#           {
#             "text": "yellow work vest"
#           },
#           {
#             "text": "dark colored pants"
#           },
#           {
#             "text": "white hardhat"
#           },
#           {
#             "text": "Armour mask"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "past"
#         },
#         "text": "was",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "He"
#       },
#       "sentence": " He was wearing a white hardhat, an orange and yellow work vest, and dark colored pants, with a black Under Armour mask covering his face, according to the FBI.",
#       "object": {
#         "text": "a white hardhat, an orange and yellow work vest, and dark colored pants",
#         "keywords": [
#           {
#             "text": "yellow work vest"
#           },
#           {
#             "text": "dark colored pants"
#           },
#           {
#             "text": "white hardhat"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "wear",
#           "tense": "past"
#         },
#         "text": "was wearing",
#         "normalized": "be wear"
#       }
#     },
#     {
#       "subject": {
#         "text": "his face",
#         "keywords": [
#           {
#             "text": "face"
#           }
#         ]
#       },
#       "sentence": " He was wearing a white hardhat, an orange and yellow work vest, and dark colored pants, with a black Under Armour mask covering his face, according to the FBI.",
#       "object": {
#         "text": "a black Under Armour mask",
#         "keywords": [
#           {
#             "text": "Armour mask"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "cover",
#           "tense": "present"
#         },
#         "text": "covering",
#         "normalized": "cover"
#       }
#     },
#     {
#       "subject": {
#         "text": "an orange and yellow work vest, and dark colored pants",
#         "keywords": [
#           {
#             "text": "yellow work vest"
#           },
#           {
#             "text": "dark colored pants"
#           },
#           {
#             "text": "orange"
#           }
#         ]
#       },
#       "sentence": " He was wearing a white hardhat, an orange and yellow work vest, and dark colored pants, with a black Under Armour mask covering his face, according to the FBI.",
#       "object": {
#         "text": "to the FBI",
#         "keywords": [
#           {
#             "text": "FBI"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "FBI",
#             "disambiguation": {
#               "subtype": [
#                 "GovernmentAgency",
#                 "GovernmentalBody"
#               ],
#               "name": "Federal Bureau of Investigation",
#               "dbpedia_resource": "http://dbpedia.org/resource/Federal_Bureau_of_Investigation"
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "accord",
#           "tense": "present"
#         },
#         "text": "according",
#         "normalized": "accord"
#       }
#     },
#     {
#       "subject": {
#         "text": "The FBI",
#         "keywords": [
#           {
#             "text": "FBI"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "FBI",
#             "disambiguation": {
#               "subtype": [
#                 "GovernmentAgency",
#                 "GovernmentalBody"
#               ],
#               "name": "Federal Bureau of Investigation",
#               "dbpedia_resource": "http://dbpedia.org/resource/Federal_Bureau_of_Investigation"
#             }
#           }
#         ]
#       },
#       "sentence": " The FBI released a surveillance photo of the would-be robber, but it was low resolution.",
#       "object": {
#         "text": "a surveillance photo of the would-be robber",
#         "keywords": [
#           {
#             "text": "would-be robber"
#           },
#           {
#             "text": "surveillance photo"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "release",
#           "tense": "past"
#         },
#         "text": "released",
#         "normalized": "release"
#       }
#     },
#     {
#       "subject": {
#         "text": "Anyone with information about the man",
#         "keywords": [
#           {
#             "text": "information"
#           },
#           {
#             "text": "man"
#           }
#         ]
#       },
#       "sentence": " Anyone with information about the man is asked to call the Chicago office of the FBI at 312-421-6700.",
#       "object": {
#         "text": "the Chicago office of the FBI",
#         "keywords": [
#           {
#             "text": "FBI"
#           },
#           {
#             "text": "Chicago office"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Location",
#             "text": "Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ],
#               "name": "Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "FBI",
#             "disambiguation": {
#               "subtype": [
#                 "GovernmentAgency",
#                 "GovernmentalBody"
#               ],
#               "name": "Federal Bureau of Investigation",
#               "dbpedia_resource": "http://dbpedia.org/resource/Federal_Bureau_of_Investigation"
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "call",
#           "tense": "future"
#         },
#         "text": "is asked to call",
#         "normalized": "be ask to call"
#       }
#     }
#   ],
#   "retrieved_url": "http://www.chicagotribune.com/news/local/breaking/ct-fbi-chase-bank-branch-robbed-on-far-south-side-20170524-story.html",
#   "language": "en"
# }

# %% [markdown]
# ### Semantically difficult examples

# %%
url='http://www.cnbc.com/2017/05/11/caterpillar-earnings-will-beat-all-year-long-bank-of-america-says.html'

response = natural_language_understanding.analyze(
            url = url,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            ))

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 1037,
#     "features": 1
#   },
#   "retrieved_url": "https://www.cnbc.com/2017/05/11/caterpillar-earnings-will-beat-all-year-long-bank-of-america-says.html",
#   "language": "en",
#   "concepts": [
#     {
#       "text": "Bank of America",
#       "relevance": 0.955122,
#       "dbpedia_resource": "http://dbpedia.org/resource/Bank_of_America"
#     },
#     {
#       "text": "Merrill Lynch",
#       "relevance": 0.88865,
#       "dbpedia_resource": "http://dbpedia.org/resource/Merrill_Lynch"
#     },
#     {
#       "text": "Private banking",
#       "relevance": 0.571594,
#       "dbpedia_resource": "http://dbpedia.org/resource/Private_banking"
#     },
#     {
#       "text": "Stock",
#       "relevance": 0.551895,
#       "dbpedia_resource": "http://dbpedia.org/resource/Stock"
#     },
#     {
#       "text": "Troubled Asset Relief Program",
#       "relevance": 0.485637,
#       "dbpedia_resource": "http://dbpedia.org/resource/Troubled_Asset_Relief_Program"
#     },
#     {
#       "text": "Morgan Stanley",
#       "relevance": 0.46867,
#       "dbpedia_resource": "http://dbpedia.org/resource/Morgan_Stanley"
#     },
#     {
#       "text": "Stock market",
#       "relevance": 0.442562,
#       "dbpedia_resource": "http://dbpedia.org/resource/Stock_market"
#     },
#     {
#       "text": "Subprime mortgage crisis",
#       "relevance": 0.439713,
#       "dbpedia_resource": "http://dbpedia.org/resource/Subprime_mortgage_crisis"
#     },
#     {
#       "text": "Safeway Inc.",
#       "relevance": 0.428831,
#       "dbpedia_resource": "http://dbpedia.org/resource/Safeway_Inc."
#     }
#   ]
# }

# %%
text="Caterpillar earnings will 'beat all year long,' Bank of America says"

response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        semantic_roles = SemanticRolesOptions(entities = True, keywords = True)
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            ))

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 68,
#     "features": 1
#   },
#   "semantic_roles": [
#     {
#       "subject": {
#         "text": "Caterpillar earnings",
#         "keywords": [
#           {
#             "text": "Caterpillar earnings"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Company",
#             "text": "Caterpillar"
#           }
#         ]
#       },
#       "sentence": "Caterpillar earnings will 'beat all year long,' Bank of America says",
#       "action": {
#         "verb": {
#           "text": "'beat",
#           "tense": "future"
#         },
#         "text": "will 'beat",
#         "normalized": "will 'beat"
#       }
#     },
#     {
#       "subject": {
#         "text": "Bank of America",
#         "keywords": [
#           {
#             "text": "Bank"
#           },
#           {
#             "text": "America"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Company",
#             "text": "Bank of America"
#           }
#         ]
#       },
#       "sentence": "Caterpillar earnings will 'beat all year long,' Bank of America says",
#       "object": {
#         "text": "Caterpillar earnings will 'beat all year long",
#         "keywords": [
#           {
#             "text": "Caterpillar earnings"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Company",
#             "text": "Caterpillar"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "say",
#           "tense": "present"
#         },
#         "text": "says",
#         "normalized": "say"
#       }
#     }
#   ],
#   "language": "en"
# }

# %% [markdown]
# ## Expect the explosion of data volumes

# %%
url='https://en.wikipedia.org/wiki/University_of_Chicago'

response = natural_language_understanding.analyze(
            url = url,
            features = Features(
                        entities = EntitiesOptions(sentiment = True, emotion = True),
                        keywords = KeywordsOptions(sentiment = True, emotion = True),
                        concepts = ConceptsOptions(limit = 50),
                        relations = RelationsOptions(),
                        sentiment = SentimentOptions(),
                        semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        emotion = EmotionOptions(),
                        categories = CategoriesOptions()
            ))

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 5,
#     "text_characters": 50000,
#     "features": 8
#   },
#   "sentiment": {
#     "document": {
#       "score": -0.306135,
#       "label": "negative"
#     }
#   },
#   "semantic_roles": [
#     {
#       "subject": {
#         "text": "University of Illinois at Chicago",
#         "keywords": [
#           {
#             "text": "Illinois"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "University of Illinois",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "AcademicInstitution",
#                 "CollegeUniversity"
#               ],
#               "name": "University of Illinois at Urbana\u2013Champaign",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Illinois_at_Urbana\u2013Champaign"
#             }
#           },
#           {
#             "type": "Location",
#             "text": "Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ],
#               "name": "Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#             }
#           }
#         ]
#       },
#       "sentence": "For the public university in the University of Illinois System, see University of Illinois at Chicago.",
#       "action": {
#         "verb": {
#           "text": "see",
#           "tense": "present"
#         },
#         "text": "see",
#         "normalized": "see"
#       }
#     },
#     {
#       "subject": {
#         "text": "The University of Chicago (U of C, Chicago, or UChicago)",
#         "keywords": [
#           {
#             "text": "Chicago"
#           },
#           {
#             "text": "University"
#           },
#           {
#             "text": "UChicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "University of Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "Company",
#                 "PeriodicalPublisher",
#                 "CollegeUniversity"
#               ],
#               "name": "University of Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago"
#             }
#           },
#           {
#             "type": "Location",
#             "text": "Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ],
#               "name": "Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#             }
#           }
#         ]
#       },
#       "sentence": " The University of Chicago (U of C, Chicago, or UChicago) is a private research university in Chicago, Illinois.",
#       "object": {
#         "text": "a private research university in Chicago, Illinois",
#         "keywords": [
#           {
#             "text": "private research university"
#           },
#           {
#             "text": "Chicago"
#           },
#           {
#             "text": "Illinois"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Location",
#             "text": "Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ],
#               "name": "Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#             }
#           },
#           {
#             "type": "Location",
#             "text": "Illinois",
#             "disambiguation": {
#               "subtype": [
#                 "PoliticalDistrict",
#                 "AdministrativeDivision",
#                 "GovernmentalJurisdiction",
#                 "USState",
#                 "StateOrCounty"
#               ],
#               "name": "Illinois",
#               "dbpedia_resource": "http://dbpedia.org/resource/Illinois"
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "is",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "It"
#       },
#       "sentence": " It holds top-ten positions in various national and international rankings.[6] [7] [8] [9] [10]",
#       "object": {
#         "text": "top-ten positions in various national and international rankings.[6] [7] [8] [9] [10]",
#         "keywords": [
#           {
#             "text": "top-ten positions"
#           },
#           {
#             "text": "international rankings."
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "hold",
#           "tense": "present"
#         },
#         "text": "holds",
#         "normalized": "hold"
#       }
#     },
#     {
#       "subject": {
#         "text": "The university",
#         "keywords": [
#           {
#             "text": "university"
#           }
#         ],
#         "entities": []
#       },
#       "sentence": " The university is composed of the College, various graduate programs and interdisciplinary committees organized into five academic research divisions and seven professional schools.",
#       "object": {
#         "text": "composed of the College, various graduate programs and interdisciplinary committees organized into five academic research divisions and seven professional schools",
#         "keywords": [
#           {
#             "text": "academic research divisions"
#           },
#           {
#             "text": "various graduate programs"
#           },
#           {
#             "text": "interdisciplinary committees"
#           },
#           {
#             "text": "professional schools"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Shimer College",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "CollegeUniversity",
#                 "University"
#               ],
#               "name": "Shimer College",
#               "dbpedia_resource": "http://dbpedia.org/resource/Shimer_College"
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "is",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "The university",
#         "keywords": [
#           {
#             "text": "university"
#           }
#         ],
#         "entities": []
#       },
#       "sentence": " The university is composed of the College, various graduate programs and interdisciplinary committees organized into five academic research divisions and seven professional schools.",
#       "object": {
#         "text": "of the College, various graduate programs and interdisciplinary committees organized into five academic research divisions and seven professional schools",
#         "keywords": [
#           {
#             "text": "academic research divisions"
#           },
#           {
#             "text": "various graduate programs"
#           },
#           {
#             "text": "interdisciplinary committees"
#           },
#           {
#             "text": "professional schools"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Shimer College",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "CollegeUniversity",
#                 "University"
#               ],
#               "name": "Shimer College",
#               "dbpedia_resource": "http://dbpedia.org/resource/Shimer_College"
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "compose",
#           "tense": "past"
#         },
#         "text": "is composed",
#         "normalized": "be compose"
#       }
#     },
#     {
#       "subject": {
#         "text": "Beyond the arts and sciences, Chicago",
#         "keywords": [
#           {
#             "text": "arts"
#           },
#           {
#             "text": "sciences"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Location",
#             "text": "Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ],
#               "name": "Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#             }
#           }
#         ]
#       },
#       "sentence": " Beyond the arts and sciences, Chicago is also well known for its professional schools, which include the Pritzker School of Medicine, the Booth School of Business, the Law School, the School of Social Service Administration, the Harris School of Public Policy Studies, the Divinity School and the Graham School of Continuing Liberal and Professional Studies.",
#       "object": {
#         "text": "well known for its professional schools, which include the Pritzker School of Medicine, the Booth School of Business, the Law School, the School of Social Service Administration, the Harris School of Public Policy Studies, the Divinity School and the Graham School of Continuing Liberal and Professional Studies",
#         "keywords": [
#           {
#             "text": "Social Service Administration"
#           },
#           {
#             "text": "Public Policy Studies"
#           },
#           {
#             "text": "Pritzker School"
#           },
#           {
#             "text": "Continuing Liberal"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Pritzker School of Medicine",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "CollegeUniversity",
#                 "University"
#               ],
#               "name": "Pritzker School of Medicine",
#               "dbpedia_resource": "http://dbpedia.org/resource/Pritzker_School_of_Medicine"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Booth School of Business",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Booth School of Business",
#               "dbpedia_resource": "http://dbpedia.org/resource/Booth_School_of_Business"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "School of Social Service Administration",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "CollegeUniversity",
#                 "University"
#               ],
#               "name": "University of Chicago School of Social Service Administration",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_School_of_Social_Service_Administration"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Harris School of Public Policy Studies",
#             "disambiguation": {
#               "subtype": [
#                 "University"
#               ],
#               "name": "Harris School of Public Policy Studies",
#               "dbpedia_resource": "http://dbpedia.org/resource/Harris_School_of_Public_Policy_Studies"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Sonia Shankman Orthogenic School",
#             "disambiguation": {
#               "subtype": [
#                 "CollegeUniversity",
#                 "Company",
#                 "University"
#               ],
#               "name": "University of Chicago Divinity School",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Divinity_School"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Graham School of Continuing Liberal"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "is",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "Beyond the arts and sciences, Chicago",
#         "keywords": [
#           {
#             "text": "arts"
#           },
#           {
#             "text": "sciences"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Location",
#             "text": "Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ],
#               "name": "Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#             }
#           }
#         ]
#       },
#       "sentence": " Beyond the arts and sciences, Chicago is also well known for its professional schools, which include the Pritzker School of Medicine, the Booth School of Business, the Law School, the School of Social Service Administration, the Harris School of Public Policy Studies, the Divinity School and the Graham School of Continuing Liberal and Professional Studies.",
#       "object": {
#         "text": "for its professional schools, which include the Pritzker School of Medicine, the Booth School of Business, the Law School, the School of Social Service Administration, the Harris School of Public Policy Studies, the Divinity School and the Graham School of Continuing Liberal and Professional Studies",
#         "keywords": [
#           {
#             "text": "Social Service Administration"
#           },
#           {
#             "text": "Public Policy Studies"
#           },
#           {
#             "text": "Pritzker School"
#           },
#           {
#             "text": "Continuing Liberal"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Pritzker School of Medicine",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "CollegeUniversity",
#                 "University"
#               ],
#               "name": "Pritzker School of Medicine",
#               "dbpedia_resource": "http://dbpedia.org/resource/Pritzker_School_of_Medicine"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Booth School of Business",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Booth School of Business",
#               "dbpedia_resource": "http://dbpedia.org/resource/Booth_School_of_Business"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "School of Social Service Administration",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "CollegeUniversity",
#                 "University"
#               ],
#               "name": "University of Chicago School of Social Service Administration",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_School_of_Social_Service_Administration"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Harris School of Public Policy Studies",
#             "disambiguation": {
#               "subtype": [
#                 "University"
#               ],
#               "name": "Harris School of Public Policy Studies",
#               "dbpedia_resource": "http://dbpedia.org/resource/Harris_School_of_Public_Policy_Studies"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Sonia Shankman Orthogenic School",
#             "disambiguation": {
#               "subtype": [
#                 "CollegeUniversity",
#                 "Company",
#                 "University"
#               ],
#               "name": "University of Chicago Divinity School",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Divinity_School"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Graham School of Continuing Liberal"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "know",
#           "tense": "past"
#         },
#         "text": "known",
#         "normalized": "know"
#       }
#     },
#     {
#       "subject": {
#         "text": "the Pritzker School of Medicine, the Booth School of Business, the Law School, the School of Social Service Administration, the Harris School of Public Policy Studies, the Divinity School and the Graham School of Continuing Liberal and Professional Studies",
#         "keywords": [
#           {
#             "text": "Social Service Administration"
#           },
#           {
#             "text": "Public Policy Studies"
#           },
#           {
#             "text": "Pritzker School"
#           },
#           {
#             "text": "Continuing Liberal"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Pritzker School of Medicine",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "CollegeUniversity",
#                 "University"
#               ],
#               "name": "Pritzker School of Medicine",
#               "dbpedia_resource": "http://dbpedia.org/resource/Pritzker_School_of_Medicine"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Booth School of Business",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Booth School of Business",
#               "dbpedia_resource": "http://dbpedia.org/resource/Booth_School_of_Business"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "School of Social Service Administration",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "CollegeUniversity",
#                 "University"
#               ],
#               "name": "University of Chicago School of Social Service Administration",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_School_of_Social_Service_Administration"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Harris School of Public Policy Studies",
#             "disambiguation": {
#               "subtype": [
#                 "University"
#               ],
#               "name": "Harris School of Public Policy Studies",
#               "dbpedia_resource": "http://dbpedia.org/resource/Harris_School_of_Public_Policy_Studies"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Sonia Shankman Orthogenic School",
#             "disambiguation": {
#               "subtype": [
#                 "CollegeUniversity",
#                 "Company",
#                 "University"
#               ],
#               "name": "University of Chicago Divinity School",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Divinity_School"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Graham School of Continuing Liberal"
#           }
#         ]
#       },
#       "sentence": " Beyond the arts and sciences, Chicago is also well known for its professional schools, which include the Pritzker School of Medicine, the Booth School of Business, the Law School, the School of Social Service Administration, the Harris School of Public Policy Studies, the Divinity School and the Graham School of Continuing Liberal and Professional Studies.",
#       "object": {
#         "text": "its professional schools",
#         "keywords": [
#           {
#             "text": "professional schools"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "include",
#           "tense": "present"
#         },
#         "text": "include",
#         "normalized": "include"
#       }
#     },
#     {
#       "subject": {
#         "text": "The university",
#         "keywords": [
#           {
#             "text": "university"
#           }
#         ],
#         "entities": []
#       },
#       "sentence": " The university currently enrolls 5,971 undergraduate students, and 16,016 students overall.[11]",
#       "object": {
#         "text": "5,971 undergraduate students",
#         "keywords": [
#           {
#             "text": "undergraduate students"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "enroll",
#           "tense": "present"
#         },
#         "text": "enrolls",
#         "normalized": "enroll"
#       }
#     },
#     {
#       "subject": {
#         "text": "the Barack Obama Presidential Center",
#         "keywords": [
#           {
#             "text": "Barack Obama Presidential"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Barack Obama Presidential Center"
#           }
#         ]
#       },
#       "sentence": " The university is also home to the University of Chicago Press, the largest university press in the United States.[19] With an estimated completion date of 2020, the Barack Obama Presidential Center will be housed at the university and include both the Obama presidential library and offices of the Obama Foundation.[20]",
#       "object": {
#         "text": "at the university",
#         "keywords": [
#           {
#             "text": "university"
#           }
#         ],
#         "entities": []
#       },
#       "action": {
#         "verb": {
#           "text": "house",
#           "tense": "future"
#         },
#         "text": "will be housed",
#         "normalized": "will be house"
#       }
#     },
#     {
#       "subject": {
#         "text": "both the Obama presidential library and offices of the Obama Foundation.[20]",
#         "keywords": [
#           {
#             "text": "Obama presidential library"
#           },
#           {
#             "text": "Obama Foundation."
#           },
#           {
#             "text": "offices"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "Obama",
#             "disambiguation": {
#               "subtype": [
#                 "Politician",
#                 "President",
#                 "Appointer",
#                 "AwardWinner",
#                 "Celebrity",
#                 "PoliticalAppointer",
#                 "U.S.Congressperson",
#                 "USPresident",
#                 "TVActor"
#               ],
#               "name": "Barack Obama",
#               "dbpedia_resource": "http://dbpedia.org/resource/Barack_Obama"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Obama Foundation."
#           }
#         ]
#       },
#       "sentence": " The university is also home to the University of Chicago Press, the largest university press in the United States.[19] With an estimated completion date of 2020, the Barack Obama Presidential Center will be housed at the university and include both the Obama presidential library and offices of the Obama Foundation.[20]",
#       "object": {
#         "text": "the Barack Obama Presidential Center",
#         "keywords": [
#           {
#             "text": "Barack Obama Presidential"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Barack Obama Presidential Center"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "include",
#           "tense": "present"
#         },
#         "text": "include",
#         "normalized": "include"
#       }
#     },
#     {
#       "subject": {
#         "text": "The University of Chicago",
#         "keywords": [
#           {
#             "text": "University"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "University of Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "Company",
#                 "PeriodicalPublisher",
#                 "CollegeUniversity"
#               ],
#               "name": "University of Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago"
#             }
#           }
#         ]
#       },
#       "sentence": " The University of Chicago has many prominent alumni, faculty members and researchers.",
#       "object": {
#         "text": "many prominent alumni, faculty members and researchers",
#         "keywords": [
#           {
#             "text": "prominent alumni"
#           },
#           {
#             "text": "faculty members"
#           },
#           {
#             "text": "researchers"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "have",
#           "tense": "present"
#         },
#         "text": "has",
#         "normalized": "have"
#       }
#     },
#     {
#       "subject": {
#         "text": "92 Nobel laureates [21]",
#         "keywords": [
#           {
#             "text": "Nobel"
#           }
#         ]
#       },
#       "sentence": " 92 Nobel laureates [21] have been affiliated with the university as professors, students, faculty, or staff, making it the fifth most of any institution in the world.",
#       "object": {
#         "text": "affiliated with the university as professors, students, faculty, or staff",
#         "keywords": [
#           {
#             "text": "professors"
#           },
#           {
#             "text": "university"
#           },
#           {
#             "text": "students"
#           },
#           {
#             "text": "faculty"
#           }
#         ],
#         "entities": [
#           {
#             "type": "JobTitle",
#             "text": "Professor"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "past"
#         },
#         "text": "been",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "professors, students, faculty, or staff,",
#         "keywords": [
#           {
#             "text": "professors"
#           },
#           {
#             "text": "students"
#           },
#           {
#             "text": "faculty"
#           },
#           {
#             "text": "staff"
#           }
#         ],
#         "entities": [
#           {
#             "type": "JobTitle",
#             "text": "Professor"
#           }
#         ]
#       },
#       "sentence": " 92 Nobel laureates [21] have been affiliated with the university as professors, students, faculty, or staff, making it the fifth most of any institution in the world.",
#       "object": {
#         "text": "it"
#       },
#       "action": {
#         "verb": {
#           "text": "make",
#           "tense": "present"
#         },
#         "text": "making",
#         "normalized": "make"
#       }
#     },
#     {
#       "subject": {
#         "text": "53 Rhodes Scholars,[23] 25 Marshall Scholars,[24] 9 Fields Medalists,[25] 20 National Humanities Medalists,[26] 13 billionaire graduates and a plethora of members of the United States Congress and heads of state of countries all over the world.[27]",
#         "keywords": [
#           {
#             "text": "National Humanities Medalists"
#           },
#           {
#             "text": "Fields Medalists"
#           },
#           {
#             "text": "Rhodes Scholars"
#           },
#           {
#             "text": "Marshall Scholars"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Rhodes Scholars"
#           },
#           {
#             "type": "Organization",
#             "text": "Marshall Scholars"
#           },
#           {
#             "type": "Organization",
#             "text": "Fields Medalists"
#           },
#           {
#             "type": "Organization",
#             "text": "National Humanities Medalists"
#           },
#           {
#             "type": "Location",
#             "text": "United States",
#             "disambiguation": {
#               "subtype": [
#                 "Region",
#                 "AdministrativeDivision",
#                 "Country",
#                 "GovernmentalJurisdiction",
#                 "FilmEditor",
#                 "Country"
#               ],
#               "name": "United States",
#               "dbpedia_resource": "http://dbpedia.org/resource/United_States"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Congress",
#             "disambiguation": {
#               "subtype": [
#                 "Dedicator",
#                 "GovernmentalBody",
#                 "Legislature",
#                 "NaturalOrCulturalPreservationAgency"
#               ],
#               "name": "United States Congress",
#               "dbpedia_resource": "http://dbpedia.org/resource/United_States_Congress"
#             }
#           }
#         ]
#       },
#       "sentence": " Similarly, 34 faculty members and 17 alumni have been awarded the MacArthur \"Genius Grant\".[22] In addition, Chicago's alumni and faculty include 53 Rhodes Scholars,[23] 25 Marshall Scholars,[24] 9 Fields Medalists,[25] 20 National Humanities Medalists,[26] 13 billionaire graduates and a plethora of members of the United States Congress and heads of state of countries all over the world.[27]",
#       "object": {
#         "text": "Chicago's alumni and faculty",
#         "keywords": [
#           {
#             "text": "Chicago"
#           },
#           {
#             "text": "alumni"
#           },
#           {
#             "text": "faculty"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Location",
#             "text": "Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ],
#               "name": "Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "include",
#           "tense": "present"
#         },
#         "text": "include",
#         "normalized": "include"
#       }
#     },
#     {
#       "subject": {
#         "text": "The University of Chicago",
#         "keywords": [
#           {
#             "text": "University"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "University of Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "Company",
#                 "PeriodicalPublisher",
#                 "CollegeUniversity"
#               ],
#               "name": "University of Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago"
#             }
#           }
#         ]
#       },
#       "sentence": " The University of Chicago was founded by a small group of Baptist educators in 1856 through a land endowment from Senator Stephen A. Douglas.[28] Disparagingly called \"Douglas College\" by its detractors, the University of Chicago's original ten-acre campus was on the northwest corner of 35th Street and Cottage Grove Avenue, a neighborhood now known as Bronzeville.",
#       "object": {
#         "text": "founded by a small group of Baptist educators",
#         "keywords": [
#           {
#             "text": "Baptist educators"
#           },
#           {
#             "text": "small group"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "past"
#         },
#         "text": "was",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "by a small group of Baptist educators",
#         "keywords": [
#           {
#             "text": "Baptist educators"
#           },
#           {
#             "text": "small group"
#           }
#         ]
#       },
#       "sentence": " The University of Chicago was founded by a small group of Baptist educators in 1856 through a land endowment from Senator Stephen A. Douglas.[28] Disparagingly called \"Douglas College\" by its detractors, the University of Chicago's original ten-acre campus was on the northwest corner of 35th Street and Cottage Grove Avenue, a neighborhood now known as Bronzeville.",
#       "object": {
#         "text": "The University of Chicago",
#         "keywords": [
#           {
#             "text": "University"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "University of Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "Company",
#                 "PeriodicalPublisher",
#                 "CollegeUniversity"
#               ],
#               "name": "University of Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago"
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "found",
#           "tense": "past"
#         },
#         "text": "was founded",
#         "normalized": "be found"
#       }
#     },
#     {
#       "subject": {
#         "text": "the University of Chicago's original ten-acre campus",
#         "keywords": [
#           {
#             "text": "University"
#           },
#           {
#             "text": "Chicago"
#           },
#           {
#             "text": "campus"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "University of Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "Company",
#                 "PeriodicalPublisher",
#                 "CollegeUniversity"
#               ],
#               "name": "University of Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago"
#             }
#           },
#           {
#             "type": "Quantity",
#             "text": "ten-acre"
#           }
#         ]
#       },
#       "sentence": " The University of Chicago was founded by a small group of Baptist educators in 1856 through a land endowment from Senator Stephen A. Douglas.[28] Disparagingly called \"Douglas College\" by its detractors, the University of Chicago's original ten-acre campus was on the northwest corner of 35th Street and Cottage Grove Avenue, a neighborhood now known as Bronzeville.",
#       "object": {
#         "text": "on the northwest corner of 35th Street and Cottage Grove Avenue, a neighborhood now known as Bronzeville",
#         "keywords": [
#           {
#             "text": "Cottage Grove Avenue"
#           },
#           {
#             "text": "35th Street"
#           },
#           {
#             "text": "northwest corner"
#           },
#           {
#             "text": "neighborhood"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Location",
#             "text": "Bronzeville",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "past"
#         },
#         "text": "was",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "a neighborhood",
#         "keywords": [
#           {
#             "text": "neighborhood"
#           }
#         ]
#       },
#       "sentence": " The University of Chicago was founded by a small group of Baptist educators in 1856 through a land endowment from Senator Stephen A. Douglas.[28] Disparagingly called \"Douglas College\" by its detractors, the University of Chicago's original ten-acre campus was on the northwest corner of 35th Street and Cottage Grove Avenue, a neighborhood now known as Bronzeville.",
#       "object": {
#         "text": "as Bronzeville",
#         "keywords": [
#           {
#             "text": "Bronzeville"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Location",
#             "text": "Bronzeville",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "know",
#           "tense": "past"
#         },
#         "text": "known",
#         "normalized": "know"
#       }
#     },
#     {
#       "subject": {
#         "text": "Local Baptist congregations",
#         "keywords": [
#           {
#             "text": "Local Baptist congregations"
#           }
#         ]
#       },
#       "sentence": " Local Baptist congregations secured donations to help partially finance construction of the elaborate Gothic-style building, named Douglas Hall, in 1857 while loans collateralized against the Douglas land was used to secure the balance.",
#       "object": {
#         "text": "donations",
#         "keywords": [
#           {
#             "text": "donations"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "secure",
#           "tense": "past"
#         },
#         "text": "secured",
#         "normalized": "secure"
#       }
#     },
#     {
#       "subject": {
#         "text": "Local Baptist congregations",
#         "keywords": [
#           {
#             "text": "Local Baptist congregations"
#           }
#         ]
#       },
#       "sentence": " Local Baptist congregations secured donations to help partially finance construction of the elaborate Gothic-style building, named Douglas Hall, in 1857 while loans collateralized against the Douglas land was used to secure the balance.",
#       "object": {
#         "text": "finance construction of the elaborate Gothic-style building",
#         "keywords": [
#           {
#             "text": "elaborate Gothic-style building"
#           },
#           {
#             "text": "finance construction"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "help",
#           "tense": "future"
#         },
#         "text": "help",
#         "normalized": "help"
#       }
#     },
#     {
#       "subject": {
#         "text": "Local Baptist congregations",
#         "keywords": [
#           {
#             "text": "Local Baptist congregations"
#           }
#         ]
#       },
#       "sentence": " Local Baptist congregations secured donations to help partially finance construction of the elaborate Gothic-style building, named Douglas Hall, in 1857 while loans collateralized against the Douglas land was used to secure the balance.",
#       "object": {
#         "text": "construction of the elaborate Gothic-style building",
#         "keywords": [
#           {
#             "text": "elaborate Gothic-style building"
#           },
#           {
#             "text": "construction"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "finance",
#           "tense": "present"
#         },
#         "text": "finance",
#         "normalized": "finance"
#       }
#     },
#     {
#       "subject": {
#         "text": "loans collateralized against the Douglas land",
#         "keywords": [
#           {
#             "text": "Douglas land"
#           },
#           {
#             "text": "loans"
#           }
#         ]
#       },
#       "sentence": " Local Baptist congregations secured donations to help partially finance construction of the elaborate Gothic-style building, named Douglas Hall, in 1857 while loans collateralized against the Douglas land was used to secure the balance.",
#       "object": {
#         "text": "to secure the balance",
#         "keywords": [
#           {
#             "text": "balance"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "use",
#           "tense": "past"
#         },
#         "text": "was used",
#         "normalized": "be use"
#       }
#     },
#     {
#       "subject": {
#         "text": "loans collateralized against the Douglas land",
#         "keywords": [
#           {
#             "text": "Douglas land"
#           },
#           {
#             "text": "loans"
#           }
#         ]
#       },
#       "sentence": " Local Baptist congregations secured donations to help partially finance construction of the elaborate Gothic-style building, named Douglas Hall, in 1857 while loans collateralized against the Douglas land was used to secure the balance.",
#       "object": {
#         "text": "the balance",
#         "keywords": [
#           {
#             "text": "balance"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "secure",
#           "tense": "past"
#         },
#         "text": "to secure",
#         "normalized": "to secure"
#       }
#     },
#     {
#       "subject": {
#         "text": "the old Bronzeville campus",
#         "keywords": [
#           {
#             "text": "old Bronzeville campus"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Location",
#             "text": "Bronzeville",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           }
#         ]
#       },
#       "sentence": " In addition to its financial ties, the old Bronzeville campus left a deep and lasting legacy on the University of Chicago.",
#       "object": {
#         "text": "a deep and lasting legacy",
#         "keywords": [
#           {
#             "text": "lasting legacy"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "leave",
#           "tense": "past"
#         },
#         "text": "left",
#         "normalized": "leave"
#       }
#     },
#     {
#       "subject": {
#         "text": "The affinity for Gothic architecture",
#         "keywords": [
#           {
#             "text": "Gothic architecture"
#           },
#           {
#             "text": "affinity"
#           }
#         ]
#       },
#       "sentence": " The affinity for Gothic architecture first began in 1857 at the Bronzeville campus as did the University of Chicago's tradition of public debate as sport.",
#       "action": {
#         "verb": {
#           "text": "begin",
#           "tense": "past"
#         },
#         "text": "began",
#         "normalized": "begin"
#       }
#     },
#     {
#       "subject": {
#         "text": "The affinity for Gothic architecture",
#         "keywords": [
#           {
#             "text": "Gothic architecture"
#           },
#           {
#             "text": "affinity"
#           }
#         ]
#       },
#       "sentence": " The affinity for Gothic architecture first began in 1857 at the Bronzeville campus as did the University of Chicago's tradition of public debate as sport.",
#       "object": {
#         "text": "the University of Chicago's tradition of public debate as sport",
#         "keywords": [
#           {
#             "text": "public debate"
#           },
#           {
#             "text": "University"
#           },
#           {
#             "text": "Chicago"
#           },
#           {
#             "text": "tradition"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "University of Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "Company",
#                 "PeriodicalPublisher",
#                 "CollegeUniversity"
#               ],
#               "name": "University of Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago"
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "do",
#           "tense": "past"
#         },
#         "text": "did",
#         "normalized": "do"
#       }
#     },
#     {
#       "subject": {
#         "text": "The current quarter system",
#         "keywords": [
#           {
#             "text": "current quarter"
#           }
#         ]
#       },
#       "sentence": " [32] The current quarter system practiced at the University of Chicago was an innovation that began at the Bronzeville campus and continues uninterrupted to this day.",
#       "action": {
#         "verb": {
#           "text": "practice",
#           "tense": "past"
#         },
#         "text": "practiced",
#         "normalized": "practice"
#       }
#     },
#     {
#       "subject": {
#         "text": "The current quarter system practiced at the University of Chicago",
#         "keywords": [
#           {
#             "text": "current quarter"
#           },
#           {
#             "text": "University"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "University of Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "Company",
#                 "PeriodicalPublisher",
#                 "CollegeUniversity"
#               ],
#               "name": "University of Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago"
#             }
#           }
#         ]
#       },
#       "sentence": " [32] The current quarter system practiced at the University of Chicago was an innovation that began at the Bronzeville campus and continues uninterrupted to this day.",
#       "object": {
#         "text": "an innovation that began at the Bronzeville campus and continues uninterrupted to this day",
#         "keywords": [
#           {
#             "text": "Bronzeville campus"
#           },
#           {
#             "text": "innovation"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Location",
#             "text": "Bronzeville",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "past"
#         },
#         "text": "was",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "an innovation",
#         "keywords": [
#           {
#             "text": "innovation"
#           }
#         ]
#       },
#       "sentence": " [32] The current quarter system practiced at the University of Chicago was an innovation that began at the Bronzeville campus and continues uninterrupted to this day.",
#       "action": {
#         "verb": {
#           "text": "continue",
#           "tense": "present"
#         },
#         "text": "continues",
#         "normalized": "continue"
#       }
#     },
#     {
#       "subject": {
#         "text": "a bronze bust of the university's founding donor",
#         "keywords": [
#           {
#             "text": "bronze bust"
#           },
#           {
#             "text": "founding donor"
#           },
#           {
#             "text": "university"
#           }
#         ],
#         "entities": []
#       },
#       "sentence": " To honor Stephen A. Douglas, a bronze bust of the university's founding donor was placed in Hutchinson Commons which is today the main dining hall and student center on campus.",
#       "object": {
#         "text": "in Hutchinson Commons which is today the main dining hall and student center on campus",
#         "keywords": [
#           {
#             "text": "Hutchinson Commons"
#           },
#           {
#             "text": "main dining hall"
#           },
#           {
#             "text": "student center"
#           },
#           {
#             "text": "campus"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Location",
#             "text": "Hutchinson Commons",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "place",
#           "tense": "past"
#         },
#         "text": "was placed",
#         "normalized": "be place"
#       }
#     },
#     {
#       "subject": {
#         "text": "All"
#       },
#       "sentence": " All told these connections have led the Dean of the College and University of Chicago and Professor of History John Boyer to conclude that the University of Chicago has a \"plausible genealogy as a pre\u2013 Civil War institution\".[36]",
#       "object": {
#         "text": "these connections have led the Dean of the College and University of Chicago and Professor of History John Boyer to conclude that the University of Chicago has a \"plausible genealogy as a pre\u2013 Civil War institution",
#         "keywords": [
#           {
#             "text": "History John Boyer"
#           },
#           {
#             "text": "Civil War institution"
#           },
#           {
# ...
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.332318,
#       "emotion": {
#         "sadness": 0.147362,
#         "joy": 0.288947,
#         "fear": 0.334651,
#         "disgust": 0.044474,
#         "anger": 0.075511
#       },
#       "disambiguation": {
#         "subtype": [
#           "Location",
#           "CollegeUniversity",
#           "University"
#         ],
#         "name": "University of Chicago School of Social Service Administration",
#         "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_School_of_Social_Service_Administration"
#       },
#       "count": 3
#     },
#     {
#       "type": "Organization",
#       "text": "Booth School of Business",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.330405,
#       "emotion": {
#         "sadness": 0.198504,
#         "joy": 0.197922,
#         "fear": 0.093778,
#         "disgust": 0.042213,
#         "anger": 0.05924
#       },
#       "disambiguation": {
#         "subtype": [],
#         "name": "Booth School of Business",
#         "dbpedia_resource": "http://dbpedia.org/resource/Booth_School_of_Business"
#       },
#       "count": 4
#     },
#     {
#       "type": "Organization",
#       "text": "University of Chicago Interfraternity Council.",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.329552,
#       "emotion": {
#         "sadness": 0.068928,
#         "joy": 0.42847,
#         "fear": 0.017847,
#         "disgust": 0.088891,
#         "anger": 0.024565
#       },
#       "count": 1
#     },
#     {
#       "type": "Organization",
#       "text": "University of Chicago School Mathematics Project",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.328597,
#       "emotion": {
#         "sadness": 0.169934,
#         "joy": 0.293143,
#         "fear": 0.356562,
#         "disgust": 0.095484,
#         "anger": 0.061316
#       },
#       "count": 1
#     },
#     {
#       "type": "Facility",
#       "text": "Hyde Park",
#       "sentiment": {
#         "score": 0.10726,
#         "label": "positive"
#       },
#       "relevance": 0.324158,
#       "emotion": {
#         "sadness": 0.123469,
#         "joy": 0.497726,
#         "fear": 0.048587,
#         "disgust": 0.126997,
#         "anger": 0.083062
#       },
#       "count": 8
#     },
#     {
#       "type": "JobTitle",
#       "text": "director",
#       "sentiment": {
#         "score": 0.67118,
#         "label": "positive"
#       },
#       "relevance": 0.323916,
#       "emotion": {
#         "sadness": 0.072505,
#         "joy": 0.654929,
#         "fear": 0.048489,
#         "disgust": 0.114912,
#         "anger": 0.094431
#       },
#       "count": 6
#     },
#     {
#       "type": "Organization",
#       "text": "Graham School of Continuing Liberal",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.321001,
#       "emotion": {
#         "sadness": 0.072119,
#         "joy": 0.315062,
#         "fear": 0.078728,
#         "disgust": 0.114538,
#         "anger": 0.160434
#       },
#       "count": 3
#     },
#     {
#       "type": "Organization",
#       "text": "Marine Biological Laboratory",
#       "sentiment": {
#         "score": 0.38117,
#         "label": "positive"
#       },
#       "relevance": 0.318744,
#       "emotion": {
#         "sadness": 0.033723,
#         "joy": 0.81986,
#         "fear": 0.030528,
#         "disgust": 0.080935,
#         "anger": 0.035258
#       },
#       "disambiguation": {
#         "subtype": [],
#         "name": "Marine Biological Laboratory",
#         "dbpedia_resource": "http://dbpedia.org/resource/Marine_Biological_Laboratory"
#       },
#       "count": 3
#     },
#     {
#       "type": "Organization",
#       "text": "University of Chicago Harris School of Public Policy Studies",
#       "sentiment": {
#         "score": -0.299369,
#         "label": "negative"
#       },
#       "relevance": 0.316532,
#       "emotion": {
#         "sadness": 0.165324,
#         "joy": 0.143361,
#         "fear": 0.121754,
#         "disgust": 0.099527,
#         "anger": 0.279302
#       },
#       "count": 1
#     },
#     {
#       "type": "Organization",
#       "text": "Baptist university",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.31518,
#       "emotion": {
#         "sadness": 0.077394,
#         "joy": 0.103201,
#         "fear": 0.067271,
#         "disgust": 0.136355,
#         "anger": 0.078706
#       },
#       "count": 1
#     },
#     {
#       "type": "Organization",
#       "text": "Renmin University",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.313641,
#       "emotion": {
#         "sadness": 0.0,
#         "joy": 0.0,
#         "fear": 0.0,
#         "disgust": 0.0,
#         "anger": 0.0
#       },
#       "disambiguation": {
#         "subtype": [
#           "CollegeUniversity",
#           "University"
#         ],
#         "name": "Renmin University of China",
#         "dbpedia_resource": "http://dbpedia.org/resource/Renmin_University_of_China"
#       },
#       "count": 1
#     },
#     {
#       "type": "Organization",
#       "text": "Chicago Theological Seminary",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.312559,
#       "emotion": {
#         "sadness": 0.068387,
#         "joy": 0.221582,
#         "fear": 0.202896,
#         "disgust": 0.035969,
#         "anger": 0.044663
#       },
#       "disambiguation": {
#         "subtype": [
#           "Location",
#           "CollegeUniversity",
#           "University"
#         ],
#         "name": "Chicago Theological Seminary",
#         "dbpedia_resource": "http://dbpedia.org/resource/Chicago_Theological_Seminary"
#       },
#       "count": 1
#     },
#     {
#       "type": "Organization",
#       "text": "University of Chicago.",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.311745,
#       "emotion": {
#         "sadness": 0.0,
#         "joy": 0.0,
#         "fear": 0.0,
#         "disgust": 0.0,
#         "anger": 0.0
#       },
#       "count": 1
#     },
#     {
#       "type": "Facility",
#       "text": "Argonne National Laboratory",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.309316,
#       "emotion": {
#         "sadness": 0.023943,
#         "joy": 0.851896,
#         "fear": 0.010551,
#         "disgust": 0.081621,
#         "anger": 0.061004
#       },
#       "count": 5
#     },
#     {
#       "type": "PrintMedia",
#       "text": "New York Times",
#       "sentiment": {
#         "score": 0.465833,
#         "label": "positive"
#       },
#       "relevance": 0.308316,
#       "emotion": {
#         "sadness": 0.040877,
#         "joy": 0.708595,
#         "fear": 0.026315,
#         "disgust": 0.095636,
#         "anger": 0.164893
#       },
#       "disambiguation": {
#         "subtype": [
#           "Organization",
#           "Company",
#           "AwardPresentingOrganization",
#           "AwardWinner",
#           "CompanyShareholder",
#           "Newspaper"
#         ],
#         "name": "The New York Times",
#         "dbpedia_resource": "http://dbpedia.org/resource/The_New_York_Times"
#       },
#       "count": 5
#     },
#     {
#       "type": "Person",
#       "text": "University President Robert Maynard Hutchins",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.304093,
#       "emotion": {
#         "sadness": 0.176424,
#         "joy": 0.306851,
#         "fear": 0.030364,
#         "disgust": 0.039023,
#         "anger": 0.055183
#       },
#       "count": 1
#     },
#     {
#       "type": "Facility",
#       "text": "Regenstein Library",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.303195,
#       "emotion": {
#         "sadness": 0.082308,
#         "joy": 0.103965,
#         "fear": 0.081497,
#         "disgust": 0.047703,
#         "anger": 0.166777
#       },
#       "disambiguation": {
#         "subtype": [
#           "Location"
#         ],
#         "name": "Regenstein Library",
#         "dbpedia_resource": "http://dbpedia.org/resource/Regenstein_Library"
#       },
#       "count": 3
#     },
#     {
#       "type": "Organization",
#       "text": "University of Chicago Presents",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.302843,
#       "emotion": {
#         "sadness": 0.098008,
#         "joy": 0.161569,
#         "fear": 0.031124,
#         "disgust": 0.065743,
#         "anger": 0.079154
#       },
#       "count": 1
#     },
#     {
#       "type": "PrintMedia",
#       "text": "Chicago Tribune",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.302629,
#       "emotion": {
#         "sadness": 0.40961,
#         "joy": 0.147241,
#         "fear": 0.211734,
#         "disgust": 0.211938,
#         "anger": 0.102664
#       },
#       "disambiguation": {
#         "subtype": [
#           "AwardWinner",
#           "ComicStripSyndicate",
#           "Newspaper"
#         ],
#         "name": "Chicago Tribune",
#         "dbpedia_resource": "http://dbpedia.org/resource/Chicago_Tribune"
#       },
#       "count": 1
#     },
#     {
#       "type": "Organization",
#       "text": "Chicago Cubs",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.298261,
#       "emotion": {
#         "sadness": 0.198499,
#         "joy": 0.153494,
#         "fear": 0.076605,
#         "disgust": 0.14728,
#         "anger": 0.104229
#       },
#       "disambiguation": {
#         "subtype": [
#           "SportsTeam",
#           "ProfessionalSportsTeam"
#         ],
#         "name": "Chicago Cubs",
#         "dbpedia_resource": "http://dbpedia.org/resource/Chicago_Cubs"
#       },
#       "count": 1
#     },
#     {
#       "type": "JobTitle",
#       "text": "Professor",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.297219,
#       "emotion": {
#         "sadness": 0.267756,
#         "joy": 0.486926,
#         "fear": 0.041521,
#         "disgust": 0.072934,
#         "anger": 0.123692
#       },
#       "count": 3
#     },
#     {
#       "type": "Organization",
#       "text": "Stetson University",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.296081,
#       "emotion": {
#         "sadness": 0.144548,
#         "joy": 0.185315,
#         "fear": 0.087573,
#         "disgust": 0.077654,
#         "anger": 0.090723
#       },
#       "disambiguation": {
#         "subtype": [
#           "CollegeUniversity",
#           "University"
#         ],
#         "name": "Stetson University",
#         "dbpedia_resource": "http://dbpedia.org/resource/Stetson_University"
#       },
#       "count": 1
#     },
#     {
#       "type": "Location",
#       "text": "United States.",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.292939,
#       "emotion": {
#         "sadness": 0.0,
#         "joy": 0.0,
#         "fear": 0.0,
#         "disgust": 0.0,
#         "anger": 0.0
#       },
#       "disambiguation": {
#         "subtype": [
#           "Country"
#         ]
#       },
#       "count": 4
#     },
#     {
#       "type": "Organization",
#       "text": "Northwestern University",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.292822,
#       "emotion": {
#         "sadness": 0.140665,
#         "joy": 0.225077,
#         "fear": 0.065905,
#         "disgust": 0.065031,
#         "anger": 0.081147
#       },
#       "disambiguation": {
#         "subtype": [
#           "AwardPresentingOrganization",
#           "CollegeUniversity",
#           "University"
#         ],
#         "name": "Northwestern University",
#         "dbpedia_resource": "http://dbpedia.org/resource/Northwestern_University"
#       },
#       "count": 1
#     },
#     {
#       "type": "PrintMedia",
#       "text": "Chicago Reader",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.291564,
#       "emotion": {
#         "sadness": 0.328685,
#         "joy": 0.325786,
#         "fear": 0.101292,
#         "disgust": 0.065556,
#         "anger": 0.035121
#       },
#       "disambiguation": {
#         "subtype": [
#           "Newspaper"
#         ],
#         "name": "Chicago Reader",
#         "dbpedia_resource": "http://dbpedia.org/resource/Chicago_Reader"
#       },
#       "count": 1
#     },
#     {
#       "type": "Organization",
#       "text": "Harris School of Public Policy Studies",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.290709,
#       "emotion": {
#         "sadness": 0.055646,
#         "joy": 0.58558,
#         "fear": 0.058917,
#         "disgust": 0.109186,
#         "anger": 0.064244
#       },
#       "disambiguation": {
#         "subtype": [
#           "University"
#         ],
#         "name": "Harris School of Public Policy Studies",
#         "dbpedia_resource": "http://dbpedia.org/resource/Harris_School_of_Public_Policy_Studies"
#       },
#       "count": 2
#     }
#   ],
#   "emotion": {
#     "document": {
#       "emotion": {
#         "sadness": 0.123196,
#         "joy": 0.555102,
#         "fear": 0.064314,
#         "disgust": 0.121394,
#         "anger": 0.075708
#       }
#     }
#   },
#   "concepts": [
#     {
#       "text": "University of Chicago",
#       "relevance": 0.914971,
#       "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago"
#     },
#     {
#       "text": "Chicago",
#       "relevance": 0.273497,
#       "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#     },
#     {
#       "text": "Hyde Park, Chicago",
#       "relevance": 0.175518,
#       "dbpedia_resource": "http://dbpedia.org/resource/Hyde_Park,_Chicago"
#     },
#     {
#       "text": "University",
#       "relevance": 0.169988,
#       "dbpedia_resource": "http://dbpedia.org/resource/University"
#     },
#     {
#       "text": "South Campus Residence Hall",
#       "relevance": 0.155396,
#       "dbpedia_resource": "http://dbpedia.org/resource/South_Campus_Residence_Hall"
#     },
#     {
#       "text": "College",
#       "relevance": 0.155216,
#       "dbpedia_resource": "http://dbpedia.org/resource/College"
#     },
#     {
#       "text": "Association of American Universities",
#       "relevance": 0.147779,
#       "dbpedia_resource": "http://dbpedia.org/resource/Association_of_American_Universities"
#     },
#     {
#       "text": "Illinois",
#       "relevance": 0.146748,
#       "dbpedia_resource": "http://dbpedia.org/resource/Illinois"
#     },
#     {
#       "text": "University of Chicago Booth School of Business",
#       "relevance": 0.146302,
#       "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Booth_School_of_Business"
#     },
#     {
#       "text": "Argonne National Laboratory",
#       "relevance": 0.144737,
#       "dbpedia_resource": "http://dbpedia.org/resource/Argonne_National_Laboratory"
#     },
#     {
#       "text": "National Association of Independent Colleges and Universities",
#       "relevance": 0.138943,
#       "dbpedia_resource": "http://dbpedia.org/resource/National_Association_of_Independent_Colleges_and_Universities"
#     },
#     {
#       "text": "Chicago Maroons",
#       "relevance": 0.13862,
#       "dbpedia_resource": "http://dbpedia.org/resource/Chicago_Maroons"
#     },
#     {
#       "text": "Big Ten Conference",
#       "relevance": 0.128257,
#       "dbpedia_resource": "http://dbpedia.org/resource/Big_Ten_Conference"
#     },
#     {
#       "text": "Public university",
#       "relevance": 0.128082,
#       "dbpedia_resource": "http://dbpedia.org/resource/Public_university"
#     },
#     {
#       "text": "University of Chicago Divinity School",
#       "relevance": 0.126594,
#       "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Divinity_School"
#     }
#   ],
#   "categories": [
#     {
#       "score": 0.754096,
#       "label": "/technology and computing/software/databases"
#     },
#     {
#       "score": 0.413422,
#       "label": "/news"
#     },
#     {
#       "score": 0.377416,
#       "label": "/education/graduate school"
#     }
#   ],
#   "warnings": [
#     "Text content exceeds 50000 character limit. Only first 50000 characters processed..."
#   ]
# }

# %% [markdown]
# ## Running Tweets through NLU

# %%
directory = 'C://Users//IBM_ADMIN//Documents//Teaching//Data Projects//Text//Tweets//'
    
file = 'jeep_new.txt'
path = directory + file

# %%
tweets = pd.read_csv(path,sep='\t', names = ['id', 'lang', 'created_at', 'screen_name', \
                                                       'name', 'location', 'retweet_count', 'text'])

tweets = tweets[tweets['text'].str.contains("love|hate", case=False)==True]

tweets = tweets.sample(n=1000)

# %%
tweets.head(5)
# Out:
#                  id lang                      created_at      screen_name  \
# 41958  9.238661e+17   en  Fri Oct 27 10:56:46 +0000 2017    harDCor_barra
# 13614  9.225938e+17   en  Mon Oct 23 22:41:12 +0000 2017       FieldsCJDR
# 56150  9.230461e+17   en  Wed Oct 25 04:38:27 +0000 2017         danticvs
# 66256  9.228317e+17   en  Tue Oct 24 14:26:43 +0000 2017      morgan_xc17
# 10136  9.220377e+17   en  Sun Oct 22 09:51:28 +0000 2017  Addicted2Emison
#
#                    name                      location  retweet_count  \
# 41958  Emperor Grunfeld                           NaN            0.0
# 13614        FieldsCJDR                   Sanford, FL            0.0
# 56150          danticvs                           FLA            0.0
# 66256      Morgan Evans  Locust Grove,GA ✈️Deland, FL            0.0
# 10136  wayhaught earper   Vancouver, British Columbia            0.0
#
#                                                     text
# 41958  @JimmyDonofrio @md_dc I love the touch of ligh...
# 13614  A royal pair. 📸: Victoria D. #jeep #itsajeepth...
# 56150  📷 bertmacklin-atf: The Kaiser-Jeep 1969 Bolide...
# 66256  RT @JamieXC16: Happy Birthday to the only pers...
# 10136  RT @nowhere897: I don’t know why, but I’d love...

# %%
#Take a small sample
#tweets_eng = tweets[tweets['lang']=='en'].reset_index(drop=True).sample(frac=0.01, replace=True)
tweets_eng = tweets[tweets['lang']=='en'].reset_index(drop=True).head(10)

# %%
len(tweets_eng)
# Out:
# 10

# %%
# For NLU we DO NOT have to remove special characters to avoid problems with analysis
tweets_eng['text_clean'] = tweets_eng['text'].map(lambda x: re.sub('[^a-zA-Z0-9 @ . , : - _]', '', str(x)))

# %%
pd.set_option('display.max_colwidth', 150)
pd.set_option('display.max_rows', 10)
tweets_eng[['text']].head(5)
# Out:
#                                                                                                                                            text
# 0                                                                   @JimmyDonofrio @md_dc I love the touch of light brown for the Jeep interior
# 1  A royal pair. 📸: Victoria D. #jeep #itsajeepthing #jeeplove #jeeplife #wrangler #jeepwrangler #jeepporn #jeepfamily… https://t.co/nYHFjlNght
# 2                          📷 bertmacklin-atf: The Kaiser-Jeep 1969 Bolide XJ-002 Concept. I am in love. Want one! #jeep https://t.co/Kk0h0BQFry
# 3              RT @JamieXC16: Happy Birthday to the only person I would listen to loud country music in a muddy Jeep with. Love you Morgan!!💕😁…
# 4                                             RT @nowhere897: I don’t know why, but I’d love to see #WayHaught driving around in Waverly’s Jeep

# %%
# Read individual columns
raw_id = tweets_eng["id"].values
raw_text = tweets_eng["text"].values

# %%
raw_text
# Out:
# array([ '@JimmyDonofrio @md_dc I love the touch of light brown for the Jeep interior',
#        'A royal pair. 📸: Victoria D. #jeep #itsajeepthing #jeeplove #jeeplife #wrangler #jeepwrangler #jeepporn #jeepfamily… https://t.co/nYHFjlNght',
#        '📷 bertmacklin-atf: The Kaiser-Jeep 1969 Bolide XJ-002 Concept. I am in love. Want one! #jeep https://t.co/Kk0h0BQFry',
#        'RT @JamieXC16: Happy Birthday to the only person I would listen to loud country music in a muddy Jeep with. Love you Morgan!!💕😁…',
#        'RT @nowhere897: I don’t know why, but I’d love to see #WayHaught driving around in Waverly’s Jeep',
#        'See that black classic jeep in the background... Lovely 😍 😍 😘 https://t.co/y2D0AjS3AH',
#        'Needs a little love but hey ya girls got a jeep again https://t.co/Q2Vfvj84Xp',
#        'I love my jeep but the amount of gas this thing burns thru is ridiculous',
#        'RT @jeepfederation: You love your Jeep but also want to drive a Tank! #wranglerLIFE #beatank https://t.co/PXNbTNmqHw',
#        '@lindarutter You go Dad! Nice looking ride for a deserving patriot. We are a two Jeep family - love our Jeeps!'], dtype=object)

# %%
# Set up lists to collect sentiments, and scores
sentiment_list = []
score_list = []

# carry over existing values
tweet_id = []
tweet_list = []

# %%
count = 0
for raw_id, raw_text in \
zip(raw_id, raw_text):
    response = natural_language_understanding.analyze(
        language = "en", #do not NLU to guess language on Tweets
        text=raw_text,
        
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            ))

    if "label" in response["sentiment"]["document"]:
        sentiment_list.append(str(response["sentiment"]["document"]["label"]))
    else:
        sentiment_list.append("NA") 

    if "score" in response["sentiment"]["document"]:
        score_list.append(str(response["sentiment"]["document"]["score"]))
    else:
        score_list.append("0") 

    tweet_list.append(raw_text)
    tweet_id.append(raw_id)
    #print(count)
    #print(tweet_list)
    #print(tweet_id)
    count += 1

# %% [markdown]
# #### Dealing with nested JSONs

# %%
response
# Out:
# {'language': 'en',
#  'sentiment': {'document': {'label': 'positive', 'score': 0.883441}},
#  'usage': {'features': 1, 'text_characters': 110, 'text_units': 1}}

# %%
response["sentiment"]
# Out:
# {'document': {'label': 'positive', 'score': 0.883441}}

# %%
response["sentiment"]["document"]
# Out:
# {'label': 'positive', 'score': 0.883441}

# %%
response["sentiment"]["document"]["label"]
# Out:
# 'positive'

# %%
response["sentiment"]["document"]["score"]
# Out:
# 0.883441

# %% [markdown]
# #### Combining results together

# %%
# Create a dataframe from the results
column_names = ["Tweet_Id", "Tweet_Text", "NLU_Sentiment", "NLU_Score"]
nlu_results = [tweet_id, tweet_list, sentiment_list, score_list]
results_dict = dict(zip(column_names,nlu_results))
results = pd.DataFrame.from_dict(results_dict, orient='columns')
results = results[column_names]   # set specific column order

# %%
results.head(10)
# Out:
#        Tweet_Id  \
# 0  9.238661e+17
# 1  9.225938e+17
# 2  9.230461e+17
# 3  9.228317e+17
# 4  9.220377e+17
# 5  9.227348e+17
# 6  9.233692e+17
# 7  9.236570e+17
# 8  9.226811e+17
# 9  9.230392e+17
#
#                                                                                                                                      Tweet_Text  \
# 0                                                                   @JimmyDonofrio @md_dc I love the touch of light brown for the Jeep interior
# 1  A royal pair. 📸: Victoria D. #jeep #itsajeepthing #jeeplove #jeeplife #wrangler #jeepwrangler #jeepporn #jeepfamily… https://t.co/nYHFjlNght
# 2                          📷 bertmacklin-atf: The Kaiser-Jeep 1969 Bolide XJ-002 Concept. I am in love. Want one! #jeep https://t.co/Kk0h0BQFry
# 3              RT @JamieXC16: Happy Birthday to the only person I would listen to loud country music in a muddy Jeep with. Love you Morgan!!💕😁…
# 4                                             RT @nowhere897: I don’t know why, but I’d love to see #WayHaught driving around in Waverly’s Jeep
# 5                                                         See that black classic jeep in the background... Lovely 😍 😍 😘 https://t.co/y2D0AjS3AH
# 6                                                                 Needs a little love but hey ya girls got a jeep again https://t.co/Q2Vfvj84Xp
# 7                                                                      I love my jeep but the amount of gas this thing burns thru is ridiculous
# 8                          RT @jeepfederation: You love your Jeep but also want to drive a Tank! #wranglerLIFE #beatank https://t.co/PXNbTNmqHw
# 9                                @lindarutter You go Dad! Nice looking ride for a deserving patriot. We are a two Jeep family - love our Jeeps!
#
#   NLU_Sentiment  NLU_Score
# 0      positive   0.734282
# 1       neutral        0.0
# 2      positive   0.853089
# 3      positive   0.767229
# 4       neutral        0.0
# 5      positive   0.673325
# 6       neutral        0.0
# 7      negative  -0.705518
# 8       neutral        0.0
# 9      positive   0.883441

# %%
# Data Export
outfile = "jeep_with_sentiment.xlsx"
outpath = directory + outfile

writer = pd.ExcelWriter(outpath, engine = "xlsxwriter")
results.to_excel(writer)
writer.save()
